# %% [markdown]
# <a href="https://colab.research.google.com/github/Jetpreethi/airflow_data/blob/main/stage3_success.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load data
df = pd.read_csv("/content/stores_data_set.csv")

# Perform data cleaning
df.drop_duplicates(inplace=True)
df.fillna({"column_name": "default_value"}, inplace=True)

# Save cleaned data
df.to_csv("cleaned_store_data.csv", index=False)

print("Data cleaning complete. Cleaned data saved to 'cleaned_store_data.csv'.")
# Out:
# Data cleaning complete. Cleaned data saved to 'cleaned_store_data.csv'.

# %%
pip install mysql-connector-python

# %%
import pandas as pd

df = pd.read_csv("/content/cleaned_store_data.csv")

# %%
df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
import mysql.connector
import sqlalchemy

# %%
client = mysql.connector.connect(host="data2.ctq8cqeeq8hk.ap-south-1.rds.amazonaws.com",user="admin",password="rootpassword",port=3306)

cursor = client.cursor()

cursor.execute("CREATE DATABASE STORES")

# %%
cursor.execute("SHOW DATABASES")

for i in cursor:
  print(i)
# Out:
# ('STORE',)
# ('STORES',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
engine=sqlalchemy.create_engine('mysql+mysqlconnector://admin:rootpassword@data2.ctq8cqeeq8hk.ap-south-1.rds.amazonaws.com:3306/STORES')

# %%
df.to_sql("cleaned",engine)
# Out:
# 45

# %%
client = mysql.connector.connect(host="data2.ctq8cqeeq8hk.ap-south-1.rds.amazonaws.com",user="admin",password="rootpassword",database="STORES")

# %%
my_cursor=client.cursor()

# %%
my_cursor.execute("SELECT * FROM cleaned")

for i in my_cursor.fetchall():
  print(i)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-33-d243228b375e> in <cell line: 1>()
# ----> 1 my_cursor.execute("SELECT * FROM cleaned")
#       2
#       3 for i in my_cursor.fetchall():
#       4   print(i)
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     328         except (ProgrammingError, ReferenceError) as err:
#     329             raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 330         self._connection.handle_unread_result()
#     331
#     332         stmt = b""
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in handle_unread_result(self, prepared)
#    1042             self.consume_results()
#    1043         elif unread_result:
# -> 1044             raise InternalError("Unread result found")
#    1045
# ...

# %%
x = engine.connect()

data = pd.read_sql_table("cleaned",con=x)
data
# Out:
#     index  Store Type    Size
# 0       0      1    A  151315
# 1       1      2    A  202307
# 2       2      3    B   37392
# 3       3      4    A  205863
# 4       4      5    B   34875
# 5       5      6    A  202505
# 6       6      7    B   70713
# 7       7      8    A  155078
# 8       8      9    B  125833
# 9       9     10    B  126512
# 10     10     11    A  207499
# 11     11     12    B  112238
# 12     12     13    A  219622
# 13     13     14    A  200898
# 14     14     15    B  123737
# 15     15     16    B   57197
# 16     16     17    B   93188
# 17     17     18    B  120653
# 18     18     19    A  203819
# 19     19     20    A  203742
# 20     20     21    B  140167
# 21     21     22    B  119557
# 22     22     23    B  114533
# 23     23     24    A  203819
# 24     24     25    B  128107
# 25     25     26    A  152513
# 26     26     27    A  204184
# 27     27     28    A  206302
# 28     28     29    B   93638
# 29     29     30    C   42988
# ...
